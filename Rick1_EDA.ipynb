# %%
import pandas as pd
import numpy as np
import time
import re
import nltk
from IPython.display import display, HTML

# %%
df = pd.read_csv('data/judge-1377884607_tweet_product_company.csv', encoding='ISO-8859-1')

# %%
re_single_quotes = r"'([a-zA-Z]+(?:[-'][a-zA-Z]+)*)'"

# %%
df['occurs'] = df['tweet_text'].str.contains(re_single_quotes)
# Out:
# C:\Users\Rick\anaconda3\envs\learn-env\lib\site-packages\pandas\core\strings.py:2001: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)

# %%
df['RT'] = df['tweet_text'].str.contains('RT')
df.groupby('is_there_an_emotion_directed_at_a_brand_or_product')['RT'].value_counts(normalize=True)
# Out:
# is_there_an_emotion_directed_at_a_brand_or_product  RT
# I can't tell                                        False    0.801282
#                                                     True     0.198718
# Negative emotion                                    False    0.773684
#                                                     True     0.226316
# No emotion toward brand or product                  False    0.689495
#                                                     True     0.310505
# Positive emotion                                    False    0.716588
#                                                     True     0.283412
# Name: RT, dtype: float64

# %%
df_filtered = df.loc[df['occurs']==True]

# %%
pd.set_option('display.max_colwidth', 300)
pd.set_option('display.width', 300)

# %%
display(HTML(df.to_html(index=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>tweet_text</th>
#       <th>emotion_in_tweet_is_directed_at</th>
#       <th>is_there_an_emotion_directed_at_a_brand_or_product</th>
#       <th>occurs</th>
#       <th>RT</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>.@wesley83 I have a 3G iPhone. After 3 hrs tweeting at #RISE_Austin, it was dead!  I need to upgrade. Plugin stations at #SXSW.</td>
#       <td>iPhone</td>
#       <td>Negative emotion</td>
#       <td>False</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <td>@jessedee Know about @fludapp ? Awesome iPad/iPhone app that you'll likely appreciate for its design. Also, they're giving free Ts at #SXSW</td>
#       <td>iPad or iPhone App</td>
#       <td>Positive emotion</td>
#       <td>False</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <td>@swonderlin Can not wait for #iPad 2 also. They should sale them down at #SXSW.</td>
# ...

# %%
df['tweet_text'] = df['tweet_text'].fillna(value='')

# %%
df_neutral = df.loc[df['is_there_an_emotion_directed_at_a_brand_or_product'] == 'No emotion toward brand or product']
df_positive = df.loc[df['is_there_an_emotion_directed_at_a_brand_or_product'] == 'Positive emotion']
df_negative = df.loc[df['is_there_an_emotion_directed_at_a_brand_or_product'] == 'Negative emotion']
df_confused = df.loc[df['is_there_an_emotion_directed_at_a_brand_or_product'] == "I can't tell"]

# %%
df['is_there_an_emotion_directed_at_a_brand_or_product'].value_counts()
# Out:
# No emotion toward brand or product    5389
# Positive emotion                      2978
# Negative emotion                       570
# I can't tell                           156
# Name: is_there_an_emotion_directed_at_a_brand_or_product, dtype: int64

# %%
df_negative['emotion_in_tweet_is_directed_at'].value_counts()
# Out:
# iPad                               125
# iPhone                             103
# Apple                               95
# Google                              68
# iPad or iPhone App                  63
# Other Google product or service     47
# Android App                          8
# Android                              8
# Other Apple product or service       2
# Name: emotion_in_tweet_is_directed_at, dtype: int64

# %%
#df.dropna(subset=['tweet_text'], axis=0, inplace=True)
